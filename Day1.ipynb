# %%
x = "..."
y = list(map(int, x))
pt1 = 0
pt2 = 0
lilen = int(len(y))
half = int(len(y)/2)

def part_one():
    total = 0
    for idx in range(lilen):
        if idx == 0 and y[idx] == y[len(y)-1]: # check the first one vs last
            total+= y[idx]
        elif y[idx] == y[idx-1]: # check current vs. last
            total+= y[idx]
    return total

def part_two():
    total = 0
    for idx in range(lilen):
        newloc = idx + half # find position (to check against) half way around the list
        if newloc >= lilen: # if greater then list length, minus list length
            newloc = newloc - lilen
        if y[newloc] == y[idx]: # check new location vs. current
            total += y[idx]
    return total
            
        
print("Day 1, part 1:", part_one())
print("Day 1, part 2:", part_two())
# Out:
# Day 1, part 1: 1223
# Day 1, part 2: 1284
